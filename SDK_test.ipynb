# %%
from labellerr.client import LabellerrClient
from labellerr.core.datasets import create_dataset_from_local
from labellerr.core.annotation_templates import create_template
from labellerr.core.projects import create_project
from labellerr.core.schemas import *

import uuid

# %%
from dotenv import dotenv_values

config = dotenv_values(".env")

API_KEY = config["API-KEY"]
API_SECRET = config["API-SECRET"]
CLIENT_ID = config["CLIENT_ID"]

# %%
# Initialize client
client = LabellerrClient(api_key=API_KEY, api_secret=API_SECRET, client_id=CLIENT_ID)

# %%
img_dataset_path = r"D:\Professional\GitHub\LABIMP-8041\sample_img_dataset"

# %%
# 1. Create dataset

dataset = create_dataset_from_local(
    client=client,
    dataset_config=DatasetConfig(dataset_name="My Dataset", data_type="image"),
    folder_to_upload=img_dataset_path
)

# %%
dataset.dataset_id
# Out:
# '1c8b2a05-0321-44fd-91e3-2ea911382cf9'

# %% [raw]
# '1c8b2a05-0321-44fd-91e3-2ea911382cf9'

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

dataset.status()

# %%
from labellerr.core.schemas.annotation_templates import AnnotationQuestion, QuestionType, CreateTemplateParams

# 2. Create annotation template

template = create_template(
    client=client,
    params=CreateTemplateParams(
        template_name="My Template",
        data_type=DatasetDataType.image,
        questions=[
            AnnotationQuestion(
                question_number=1,
                question="Object",
                question_id=str(uuid.uuid4()),
                question_type=QuestionType.bounding_box,
                required=True,
                color="#FF0000"
            )
        ]
    )
)

# %%
# 3. Create project

project = create_project(
    client=client,
    params=CreateProjectParams(
        project_name="My Project",
        data_type=DatasetDataType.image,
        rotations=RotationConfig(
            annotation_rotation_count=1,
            review_rotation_count=1,
            client_review_rotation_count=1
        )
    ),
    datasets=[dataset],
    annotation_template=template
)

print(f"✓ Project created: {project.project_id}")
# Out:
# ---------------------------------------------------------------------------
# LabellerrError                            Traceback (most recent call last)
# Cell In[34], line 3
#       1 # 3. Create project
# ----> 3 project = create_project(
#       4     client=client,
#       5     params=CreateProjectParams(
#       6         project_name="My Project",
#       7         data_type=DatasetDataType.image,
#       8         rotations=RotationConfig(
#       9             annotation_rotation_count=1,
#      10             review_rotation_count=1,
#      11             client_review_rotation_count=1
#      12         )
#      13     ),
#      14     datasets=[dataset],
#      15     annotation_template=template
#      16 )
#      18 print(f"✓ Project created: {project.project_id}")
#
# File d:\Professional\GitHub\LABIMP-8041\SDKPython\labellerr\core\projects\__init__.py:42, in create_project(client, params, datasets, annotation_template)
#      40 for dataset in datasets:
#      41     if dataset.files_count == 0:
# ---> 42         raise LabellerrError(f"Dataset {dataset.dataset_id} has no files")
#      44 attached_datasets = [dataset.dataset_id for dataset in datasets]
#      46 unique_id = str(uuid.uuid4())
#
# LabellerrError: Dataset 1c8b2a05-0321-44fd-91e3-2ea911382cf9 has no files
